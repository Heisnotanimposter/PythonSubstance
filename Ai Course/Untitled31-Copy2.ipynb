# %%
import pyupbit
import seaborn as sns

# %%
ㅇㅇ
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 score1 = pd.Series({'국어=1','영어=2','수학=2','사회a=1','사회b=1','한국사=1'})
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:451, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     449         data = data.copy()
#     450 else:
# --> 451     data = sanitize_array(data, index, dtype, copy)
#     453     manager = get_option("mode.data_manager")
#     454     if manager == "block":
#
# File ~\anaconda3\lib\site-packages\pandas\core\construction.py:581, in sanitize_array(data, index, dtype, copy, raise_cast_failure, allow_2d)
#     578 else:
#     579     if isinstance(data, (set, frozenset)):
#     580         # Raise only for unordered sets, e.g., not for dict_keys
# --> 581         raise TypeError(f"'{type(data).__name__}' type is unordered")
# ...

# %%
crashes = sns.load_dataset('car_crashes')
print(crashes)
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df = crashes[['speeding','alcohol']]
len(df)
df.head(-5)
# Out:
#     speeding  alcohol
# 0      7.332    5.640
# 1      7.421    4.525
# 2      6.510    5.208
# 3      4.032    5.824
# 4      4.200    3.360
# 5      5.032    3.808
# 6      4.968    3.888
# 7      6.156    4.860
# 8      2.006    1.593
# 9      3.759    5.191
# 10     2.964    3.900
# 11     9.450    7.175
# 12     5.508    4.437
# 13     4.608    4.352
# 14     3.625    4.205
# 15     2.669    3.925
# 16     4.806    4.272
# 17     4.066    4.922
# 18     7.175    6.765
# 19     5.738    4.530
# 20     4.250    4.000
# 21     1.886    2.870
# 22     3.384    3.948
# 23     2.208    2.784
# 24     2.640    5.456
# 25     6.923    5.474
# 26     8.346    9.416
# 27     1.937    5.215
# 28     5.439    4.704
# 29     4.060    3.480
# 30     1.792    3.136
# 31     3.496    4.968
# 32     3.936    3.567
# 33     6.552    5.208
# 34     5.497   10.038
# 35     3.948    4.794
# 36     6.368    5.771
# 37     4.224    3.328
# 38     9.100    5.642
# 39     3.774    4.218
# ...

# %%
df.tail()
# Out:
#     speeding  alcohol
# 46     2.413    3.429
# 47     4.452    3.498
# 48     8.092    6.664
# 49     4.968    4.554
# 50     7.308    5.568

# %%
sub = df.head() - df.tail()

# %%
sub
# Out:
#     speeding  alcohol
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN
# 46       NaN      NaN
# 47       NaN      NaN
# 48       NaN      NaN
# 49       NaN      NaN
# 50       NaN      NaN
